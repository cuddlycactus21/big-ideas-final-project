# %% [markdown]
# Masons Dataset
# Dataset that has the condemned and dead-end properties.
# https://data.wprdc.org/dataset/condemned-properties/resource/0a963f26-eb4b-4325-bbbc-3ddf6a871410

# %%
import pandas as pd

file = pd.read_csv('condemnedanddead-endproperties.csv')
file.head()
# Out:
#      _id         parcel_id                                address  zip_code  \
# 0  62701  0015L00194000000     113 CHALFONT ST, Pittsburgh, 15210     15210
# 1  62702  0015L00194000000     113 CHALFONT ST, Pittsburgh, 15210     15210
# 2  62703  0232B00068000000  1825 MAPLEWOOD AVE, Pittsburgh, 15221     15221
# 3  62704  0232B00068000000  1825 MAPLEWOOD AVE, Pittsburgh, 15221     15221
# 4  62705  0011A00235000000           No primary address specified     15219
#
#                      owner                property_type create_date  \
# 0        JAMES CHARMETTE Y  Condemned/Dead End Property  2020-08-26
# 1        JAMES CHARMETTE Y  Condemned/Dead End Property  2024-01-04
# 2  SLOAN MALCOLM & LILLIAN  Condemned/Dead End Property  2024-02-07
# 3  SLOAN MALCOLM & LILLIAN  Condemned/Dead End Property  2024-02-07
# 4     BLAIR WILLIAM HOWARD  Condemned/Dead End Property  2020-12-03
#
#   latest_inspection_result  latest_inspection_score     record_number  \
# ...
