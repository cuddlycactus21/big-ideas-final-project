# %% [markdown]
# Luke's Dataset

# %%
import pandas as pd
fields = pd.read_csv("parks.csv")
fields.head(10)
# Out:
#    _id          id                       name                   type  \
# 0    1  2111959181             Able Long Park                   Park
# 1    2  1109513049    Albert Turk Graham Park                   Park
# 2    3  1544096765                 Alcoa Park                   Park
# 3    4  1212681573          Allegheny Commons                   Park
# 4    5   954863286     Allegheny Landing Park                   Park
# 5    6   223959093  Allegheny Riverfront Park                   Park
# 6    7  1596467340        Alpine Gardens Park                   Park
# 7    8  1829922263                 Alton Park                   Park
# 8    9  2049886968             Amber Triangle  Traffic Island/Median
# 9   10  1047118140                 Ammon Park                   Park
#
#   maintenance_responsibility  \
# 0           Parks - Southern
# 1           Parks - Schenley
# 2           Parks - Northern
# 3           Parks - Northern
# 4           Parks - Northern
# ...
